# %%
import cv2

# %%
videoPath = 'D:/tennis_v2/test_02.mp4'

# %%
# 创建HOG描述符
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# 打开视频文件或摄像头
cap = cv2.VideoCapture(videoPath)  # 如果使用摄像头，可以替换为0

while True:
    # 读取一帧
    ret, frame = cap.read()
    if not ret:
        break

    # 检测人
    boxes, weights = hog.detectMultiScale(frame, winStride=(8, 8), padding=(8, 8), scale=1.05)

    # 绘制检测框
    for (x, y, w, h) in boxes:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # 显示当前帧
    cv2.imshow('Detected People', frame)

    # 按 'q' 键退出
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 释放资源
cap.release()
cv2.destroyAllWindows()

# %%
video_input_path = 'e:/TennisProject-main/inference/test.mp4'
video_output_path = 'e:/tennis_v2/inference/output_v11_' + video_input_path.split('/')[-1]
video_output_path

model = RTDETR("rtdetr-l.pt")
results = model.track(source=video_input_path, conf=0.3, iou=0.5, device='cuda', save=True, persist=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/266) e:\TennisProject-main\inference\test.mp4: 640x640 14 persons, 2 tennis rackets, 4 chairs, 3 clocks, 1822.9ms
# video 1/1 (frame 2/266) e:\TennisProject-main\inference\test.mp4: 640x640 12 persons, 2 tennis rackets, 4 chairs, 3 clocks, 2150.4ms
# video 1/1 (frame 3/266) e:\TennisProject-main\inference\test.mp4: 640x640 14 persons, 2 tennis rackets, 5 chairs, 3 clocks, 2140.5ms
# ...

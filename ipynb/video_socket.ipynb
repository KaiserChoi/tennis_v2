# %%
import websocket
import threading
import time
import json
import requests
import cv2
import matplotlib.pyplot as plt

# %%
url = "http://jason-shawjaine.top:7001/tennisVideo"
response  = requests.get(url)
if response.status_code == 200:
    print(response.json())
else:
    print(f'Error: {response.status_code}')
# Out:
# {'code': 200, 'data': {'videoUrl': 'rtmp://rtmp03open.ys7.com:1935/v3/openlive/BB8121883_1_2?expire=1740543505&id=814471363404054528&t=716c793a771dd58c8e2d21e3b6451c959c2783afc997c0656843bfd13fff9878&ev=100'}}

# %%
rtmp_addr = response.json()['data']['videoUrl']
print(rtmp_addr)
cap = cv2.VideoCapture(rtmp_addr)

cap = cv2.VideoCapture(rtmp_addr)#读取视频流
while(cap.isOpened()):
    ret, frame = cap.read()
    print('success')
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# rtmp://rtmp03open.ys7.com:1935/v3/openlive/BB8121883_1_2?expire=1740543505&id=814471363404054528&t=716c793a771dd58c8e2d21e3b6451c959c2783afc997c0656843bfd13fff9878&ev=100
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# ...

# %% [markdown]
# ### socket传输（有用）

# %%
def on_message(ws, message):
    print(f"Received: {message}")

def on_error(ws, error):
    print(f"Error: {error}")

def on_close(ws, close_status_code, close_msg):
    print("### closed ###")

def on_open(ws):
    print("Opened connection")


json_data_dict = {"msg": {
    "cxk": "zzzxcw1sss"
}}

json_string = json.dumps(json_data_dict)  # indent=4 使输出更易读

# %%
# 在一个单独的线程中启动 WebSocket 连接
ws_url = "wss://jason-shawjaine.top:8086/general"
ws = websocket.WebSocket()
ws.connect(ws_url)
a = ws.send(json_string)
print(a)
# Out:
# 36

# %%
import cv2
import matplotlib.pyplot as plt

rtmp_url = "rtmp://rtmp03open.ys7.com:1935/v3/openlive/BB8121883_1_1?expire=1739333619&id=809396733366726656&t=5c4f64d1978ea0ed04f768dda2026eacc72cf46a8d03559a934dfe1821f376cd&ev=100"

myrtmp_addr = rtmp_url
cap = cv2.VideoCapture(myrtmp_addr)

ret, frame = cap.read()
if ret:
    cv2.imshow('My Image Window', frame)
    # Suppose your image is stored in a NumPy array called 'img_array'
    plt.imshow(frame, cmap='gray')  # 'gray' for grayscale images, else remove or change    
    plt.show()

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 接受RTMP视频（有用）

# %%
import cv2


# url = "http://admin:admin@192.168.3.11:8081"
# 程序是执行状态，但是没有打开摄像头
# url = "http://admin:123456@192.168.3.16:8081"
# 正确打开摄像头

url = "rtmp://rtmp03open.ys7.com:1935/v3/openlive/BB8121883_1_2?expire=1770968903&id=811987489337679872&t=b531b9171f1fc6a77e98cf0671fefdb5ef4357a37e662db72efd3a2ce8aadfa0&ev=100"
# 直接返回错误：[rtsp @ 000001ee2b0824c0] method DESCRIBE failed: 401 Unauthorized

# url = "rtsp://admin:123456@192.168.3.16:8554/live"
# [rtsp @ 0000019250a424c0] method DESCRIBE failed: 404 Stream Not Found  手机的摄像头会被打开，然后程序报错

print('start')
cap = cv2.VideoCapture(url)#读取视频流
while(cap.isOpened()):
    ret, frame = cap.read()
    print('success')
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# start
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# ...

# %%
import cv2

m3u8_url = "https://open.ys7.com/v3/openlive/BB8121883_1_2.m3u8?expire=1770430139&id=809727749961191424&t=7587c5c1d3c26514d0a86a0b2d8fa104891e7751ce04eacb448c94631e8eda5c&ev=100"


while True:
    cap = cv2.VideoCapture(m3u8_url)
    if not cap.isOpened():
        print("无法打开 M3U8 流")
        exit()
    ret, frame = cap.read()
    if not ret:
        break
    cv2.imshow("HLS Stream", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 无法打开 M3U8 流
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %% [markdown]
# ### m3u8

# %%
from pym3u8 import Loader
loader = Loader('https://open.ys7.com/v3/openlive/BB8121883_1_2.m3u8?expire=1770430139&id=809727749961191424&t=7587c5c1d3c26514d0a86a0b2d8fa104891e7751ce04eacb448c94631e8eda5c&ev=100', referer="", filename='stream')
loader.download()
# Out:
# Downloaded => 0.0 %
# Finished

# %%
import subprocess

subprocess.call([
    "ffmpeg", "-i" "BB8121883_1_2.m3u8", "output.mp4"
])
# Out:
# 2880417800

# %%
# 示例 (下载并解析 M3U8 文件)
import hl

m3u8_url = "your_m3u8_url.m3u8"
master_playlist = hls.load(m3u8_url)

# 获取最佳的变体 (variant)
best_variant = master_playlist.playlists[0] # 假设第一个是最佳的
for segment in best_variant.segments:
      print(segment.uri) # 打印每个ts分片的URL
      # 可以使用 requests 等库下载每个 segment.uri

# %%
import ffmpeg_streaming


video = ffmpeg_streaming.input("https://open.ys7.com/v3/openlive/BB8121883_1_2.m3u8?expire=1770430139&id=809727749961191424&t=7587c5c1d3c26514d0a86a0b2d8fa104891e7751ce04eacb448c94631e8eda5c&ev=100")

# %%
from ffmpeg_streaming import Formats, Bitrate, Representation, Size


_360p  = Representation(Size(640, 360), Bitrate(276 * 1024, 128 * 1024))
_480p  = Representation(Size(854, 480), Bitrate(750 * 1024, 192 * 1024))
_720p  = Representation(Size(1280, 720), Bitrate(2048 * 1024, 320 * 1024))

hls = video.hls(Formats.h264())
hls.representations(_360p, _480p, _720p)
hls.output('hls.m3u8')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 10
#       8 hls = video.hls(Formats.h264())
#       9 hls.representations(_360p, _480p, _720p)
# ---> 10 hls.output('hls.m3u8')
#
# File d:\python\Python3106-64\lib\site-packages\ffmpeg_streaming\_media.py:93, in Save.output(self, output, clouds, run_command, ffmpeg_bin, monitor, **options)
#      90 self.set_up()
#      92 if run_command:
# ---> 93     self.run(ffmpeg_bin, monitor, **options)
#
# File d:\python\Python3106-64\lib\site-packages\ffmpeg_streaming\_media.py:119, in Save.run(self, ffmpeg_bin, monitor, **options)
#     115 """
#     116 @TODO: add documentation
#     117 """
#     118 if async_run := options.pop('async_run', True):
# --> 119     asyncio.run(self.async_run(ffmpeg_bin, monitor, **options))
#     120 else:
#     121     self._run(ffmpeg_bin, monitor, **options)
#
# ...
